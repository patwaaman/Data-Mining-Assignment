# %%
import pandas as pd
import numpy as np
import math
import itertools
import collections
from itertools import combinations

# %%
#read transactions data from csv file
df = pd.read_excel('OnlineRetail.xlsx')

#clean the product names
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

#create basket dataframe
basket = df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
basket.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description  ...  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo    ...
# 536365       ...                  0.0                  0.0
# 536366       ...                  0.0                  0.0
# 536367       ...                  0.0                  0.0
# 536368       ...                  0.0                  0.0
# 536369       ...                  0.0                  0.0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
#
# [5 rows x 4194 columns]

# %%
#one hot encode the basket
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# 536367                            0                           0
# 536368                            0                           0
# 536369                            0                           0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                  0                                 0
# 536366                                  0                                 0
# 536367                                  0                                 0
# 536368                                  0                                 0
# 536369                                  0                                 0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                     0                              0
# 536366                                     0                              0
# 536367                                     0                              0
# 536368                                     0                              0
# 536369                                     0                              0
#
# Description  ...  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo    ...
# 536365       ...                    0                    0
# 536366       ...                    0                    0
# 536367       ...                    0                    0
# 536368       ...                    0                    0
# 536369       ...                    0                    0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                         0               0                     0
# 536366                         0               0                     0
# 536367                         0               0                     0
# 536368                         0               0                     0
# 536369                         0               0                     0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                                 0                             0
# 536366                                 0                             0
# 536367                                 0                             0
# 536368                                 0                             0
# 536369                                 0                             0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                  0                     0
# 536366                                  0                     0
# 536367                                  0                     0
# 536368                                  0                     0
# 536369                                  0                     0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                       0
# 536366                       0
# 536367                       0
# 536368                       0
# 536369                       0
#
# [5 rows x 4194 columns]

# %%
class FPNode(object):
    def __init__(self, item, count=0, parent=None):
        self.item = item
        self.count = count
        self.parent = parent
        self.children = collections.defaultdict(FPNode)

        if parent is not None:
            parent.children[item] = self

    def itempath_from_root(self):
        # Returns the top-down sequence of items from self to (but not including) the root node
        path = []
        if self.item is None:
            return path

        node = self.parent
        while node.item is not None:
            path.append(node.item)
            node = node.parent

        path.reverse()
        return path

# %%
class FPTree(object):
    def __init__(self, rank=None):
        self.root = FPNode(None)
        self.nodes = collections.defaultdict(list)
        self.cond_items = []
        self.rank = rank

    def conditional_tree(self, cond_item, minsup):
        # Find all path from root node to nodes for item
        branches = []
        count = collections.defaultdict(int)
        for node in self.nodes[cond_item]:
            branch = node.itempath_from_root()
            branches.append(branch)
            for item in branch:
                count[item] += node.count

        # Define new ordering or deep trees may have combinatorially explosion
        items = [item for item in count if count[item] >= minsup]
        items.sort(key=count.get)
        rank = {item: i for i, item in enumerate(items)}

        # Create conditional tree
        cond_tree = FPTree(rank)
        for idx, branch in enumerate(branches):
            branch = sorted([i for i in branch if i in rank],
                            key=rank.get, reverse=True)
            cond_tree.insert_itemset(branch, self.nodes[cond_item][idx].count)
        cond_tree.cond_items = self.cond_items + [cond_item]

        return cond_tree

    def insert_itemset(self, itemset, count=1):
        self.root.count += count

        if len(itemset) == 0:
            return

        # Follow existing path in tree as long as possible
        index = 0
        node = self.root
        for item in itemset:
            if item in node.children:
                child = node.children[item]
                child.count += count
                node = child
                index += 1
            else:
                break

        # Insert any remaining items
        for item in itemset[index:]:
            child_node = FPNode(item, count, node)
            self.nodes[item].append(child_node)
            node = child_node

    def is_path(self):
        if len(self.root.children) > 1:
            return False
        for i in self.nodes:
            if len(self.nodes[i]) > 1 or len(self.nodes[i][0].children) > 1:
                return False
        return True

    def print_status(self, count, colnames):
        cond_items = [str(i) for i in self.cond_items]
        if colnames:
            cond_items = [str(colnames[i]) for i in self.cond_items]
        cond_items = ", ".join(cond_items)
        print('\r%d itemset(s) from tree conditioned on items (%s)' %
              (count, cond_items), end="\n")

# %%
def setup_fptree(df, min_support):
    num_itemsets = len(df.index)        # number of itemsets in the database
    itemsets = df.values

    # support of each individual item
    item_support = np.array(np.sum(itemsets, axis=0) / float(num_itemsets))
    item_support = item_support.reshape(-1)

    items = np.nonzero(item_support >= min_support)[0]

    # Define ordering on items for inserting into FPTree
    indices = item_support[items].argsort()
    rank = {item: i for i, item in enumerate(items[indices])}

    tree = FPTree(rank)
    for i in range(num_itemsets):

        nonnull = np.where(itemsets[i, :])[0]
        itemset = [item for item in nonnull if item in rank]
        itemset.sort(key=rank.get, reverse=True)
        tree.insert_itemset(itemset)
    
    return tree, rank

# %%
def fpg_step(tree, minsup, colnames, max_len, verbose=0):

    count = 0
    items = tree.nodes.keys()
    if tree.is_path():
        # If the tree is a path, we can combinatorally generate all
        # remaining itemsets without generating additional conditional trees
        size_remain = len(items) + 1
        if max_len:
            size_remain = max_len - len(tree.cond_items) + 1
        for i in range(1, size_remain):
            for itemset in itertools.combinations(items, i):
                count += 1
                support = min([tree.nodes[i][0].count for i in itemset])
                yield support, tree.cond_items + list(itemset)
    elif not max_len or max_len > len(tree.cond_items):
        for item in items:
            count += 1
            support = sum([node.count for node in tree.nodes[item]])
            yield support, tree.cond_items + [item]

    verbose=1
    if verbose:
        tree.print_status(count, colnames)

    # Generate conditional trees to generate frequent itemsets one item larger
    if not tree.is_path() and (not max_len or max_len > len(tree.cond_items)):
        for item in items:
            cond_tree = tree.conditional_tree(item, minsup)
            for sup, iset in fpg_step(cond_tree, minsup,
                                      colnames, max_len, verbose):
                yield sup, iset

# %%
def generate_itemsets(generator, num_itemsets, colname_map):
    itemsets = []
    supports = []
    for sup, iset in generator:
        itemsets.append(frozenset(iset))
        supports.append(sup / num_itemsets)

    res_df = pd.DataFrame({'support': supports, 'itemsets': itemsets})

    if colname_map is not None:
        res_df['itemsets'] = res_df['itemsets'] \
            .apply(lambda x: frozenset([colname_map[i] for i in x]))

    return res_df

# %%
def fpgrowth(df, min_support=0.5, use_colnames=False, max_len=None, verbose=0):

    colname_map = None
    if use_colnames:
        colname_map = {idx: item for idx, item in enumerate(df.columns)}

    tree, _ = setup_fptree(df, min_support)
    minsup = math.ceil(min_support * len(df.index))  # min support as count
    generator = fpg_step(tree, minsup, colname_map, max_len, verbose)

    return generate_itemsets(generator, len(df.index), colname_map)

# %%
#create minTransactions variable to represent the minimum number of baskets for support parameter
totalTransactions = len(basket_sets.index)
min_support_calc = 0.01

print('number of baskets for analysis is', totalTransactions)
print('minimum support value is ', round(min_support_calc*100, 4), '%')

#create frequent items sets with clculated minimum support
frequent_itemsets = fpgrowth(basket_sets, min_support=min_support_calc, use_colnames=True)
frequent_itemsets.describe()
# Out:
# number of baskets for analysis is 20609
# minimum support value is  1.0 %
# 781 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (KNITTED UNION FLAG HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (RED WOOLLY HOTTIE WHITE HEART.)
# 0 itemset(s) from tree conditioned on items (SET 7 BABUSHKA NESTING BOXES)
# 0 itemset(s) from tree conditioned on items (WHITE METAL LANTERN)
# 0 itemset(s) from tree conditioned on items (CREAM CUPID HEARTS COAT HANGER)
# 2 itemset(s) from tree conditioned on items (HAND WARMER UNION JACK)
# 0 itemset(s) from tree conditioned on items (HAND WARMER UNION JACK, HAND WARMER OWL DESIGN)
# 0 itemset(s) from tree conditioned on items (HAND WARMER UNION JACK, HAND WARMER SCOTTY DOG DESIGN)
# 3 itemset(s) from tree conditioned on items (ASSORTED COLOUR BIRD ORNAMENT)
# 0 itemset(s) from tree conditioned on items (ASSORTED COLOUR BIRD ORNAMENT, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (ASSORTED COLOUR BIRD ORNAMENT, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (ASSORTED COLOUR BIRD ORNAMENT, PARTY BUNTING)
# 1 itemset(s) from tree conditioned on items (HOME BUILDING BLOCK WORD)
# 2 itemset(s) from tree conditioned on items (LOVE BUILDING BLOCK WORD)
# 0 itemset(s) from tree conditioned on items (LOVE BUILDING BLOCK WORD, HOME BUILDING BLOCK WORD)
# 0 itemset(s) from tree conditioned on items (LOVE BUILDING BLOCK WORD, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (DOORMAT NEW ENGLAND)
# 0 itemset(s) from tree conditioned on items (FELTCRAFT PRINCESS CHARLOTTE DOLL)
# 0 itemset(s) from tree conditioned on items (POPPY'S PLAYHOUSE KITCHEN)
# 1 itemset(s) from tree conditioned on items (POPPY'S PLAYHOUSE BEDROOM)
# 0 itemset(s) from tree conditioned on items (BOX OF VINTAGE ALPHABET BLOCKS)
# 0 itemset(s) from tree conditioned on items (BOX OF VINTAGE JIGSAW BLOCKS)
# 0 itemset(s) from tree conditioned on items (BOX OF 6 ASSORTED COLOUR TEASPOONS)
# 9 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, JAM MAKING SET PRINTED)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, PARTY BUNTING)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET WITH JARS, SET OF 3 CAKE TINS PANTRY DESIGN)
# 0 itemset(s) from tree conditioned on items (BATH BUILDING BLOCK WORD)
# 0 itemset(s) from tree conditioned on items (POSTAGE)
# 3 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE RED)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE RED, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE RED, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE RED, PARTY BUNTING)
# 4 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE GREEN)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKELIKE RED)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE GREEN, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE GREEN, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE GREEN, PARTY BUNTING)
# 3 itemset(s) from tree conditioned on items (SPACEBOY LUNCH BOX)
# 0 itemset(s) from tree conditioned on items (SPACEBOY LUNCH BOX, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (SPACEBOY LUNCH BOX, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (SPACEBOY LUNCH BOX, JUMBO BAG RED RETROSPOT)
# 6 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, JAM MAKING SET PRINTED)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, JUMBO BAG WOODLAND ANIMALS)
# 0 itemset(s) from tree conditioned on items (RED TOADSTOOL LED NIGHT LIGHT, RABBIT NIGHT LIGHT)
# 3 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE PINK)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELIKE RED)
# 1 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELIKE GREEN)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE PINK, REGENCY CAKESTAND 3 TIER)
# 2 itemset(s) from tree conditioned on items (ROUND SNACK BOXES SET OF4 WOODLAND)
# 0 itemset(s) from tree conditioned on items (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)
# 0 itemset(s) from tree conditioned on items (ROUND SNACK BOXES SET OF4 WOODLAND, LUNCH BAG WOODLAND)
# 2 itemset(s) from tree conditioned on items (LUNCH BOX I LOVE LONDON)
# 0 itemset(s) from tree conditioned on items (LUNCH BOX I LOVE LONDON, SPACEBOY LUNCH BOX)
# 0 itemset(s) from tree conditioned on items (LUNCH BOX I LOVE LONDON, DOLLY GIRL LUNCH BOX)
# 1 itemset(s) from tree conditioned on items (VINTAGE HEADS AND TAILS CARD GAME)
# 0 itemset(s) from tree conditioned on items (SET 2 TEA TOWELS I LOVE LONDON)
# 3 itemset(s) from tree conditioned on items (CHARLOTTE BAG DOLLY GIRL DESIGN)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG DOLLY GIRL DESIGN, RED RETROSPOT CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG DOLLY GIRL DESIGN, CHARLOTTE BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG DOLLY GIRL DESIGN, WOODLAND CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (CIRCUS PARADE LUNCH BOX)
# 0 itemset(s) from tree conditioned on items (SET/2 RED RETROSPOT TEA TOWELS)
# 0 itemset(s) from tree conditioned on items (MINI PAINT SET VINTAGE)
# 1 itemset(s) from tree conditioned on items (PAPER CHAIN KIT 50'S CHRISTMAS)
# 4 itemset(s) from tree conditioned on items (WOODEN PICTURE FRAME WHITE FINISH)
# 0 itemset(s) from tree conditioned on items (WOODEN PICTURE FRAME WHITE FINISH, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (WOODEN PICTURE FRAME WHITE FINISH, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (WOODEN PICTURE FRAME WHITE FINISH, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (WOODEN PICTURE FRAME WHITE FINISH, JUMBO STORAGE BAG SUKI)
# 2 itemset(s) from tree conditioned on items (WOODEN FRAME ANTIQUE WHITE)
# 0 itemset(s) from tree conditioned on items (WOODEN FRAME ANTIQUE WHITE, WOODEN PICTURE FRAME WHITE FINISH)
# 1 itemset(s) from tree conditioned on items (WOODEN FRAME ANTIQUE WHITE, WHITE HANGING HEART T-LIGHT HOLDER)
# 1 itemset(s) from tree conditioned on items (WOOD 2 DRAWER CABINET WHITE FINISH)
# 0 itemset(s) from tree conditioned on items (WOOD S/3 CABINET ANT WHITE FINISH)
# 0 itemset(s) from tree conditioned on items (SAVE THE PLANET MUG)
# 0 itemset(s) from tree conditioned on items (EDWARDIAN PARASOL RED)
# 1 itemset(s) from tree conditioned on items (RED HANGING HEART T-LIGHT HOLDER)
# 3 itemset(s) from tree conditioned on items (HOT WATER BOTTLE TEA AND SYMPATHY)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE TEA AND SYMPATHY, CHOCOLATE HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE TEA AND SYMPATHY, HOT WATER BOTTLE I AM SO POORLY)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE TEA AND SYMPATHY, HOT WATER BOTTLE KEEP CALM)
# 4 itemset(s) from tree conditioned on items (LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG RED RETROSPOT, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG RED RETROSPOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG RED RETROSPOT, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG RED RETROSPOT, PARTY BUNTING)
# 6 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, PARTY BUNTING)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 RETROSPOT CAKE CASES, SET OF 3 CAKE TINS PANTRY DESIGN)
# 4 itemset(s) from tree conditioned on items (JUMBO BAG PINK POLKADOT)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG PINK POLKADOT, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK POLKADOT, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK POLKADOT, LUNCH BAG  BLACK SKULL.)
# 5 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI)
# 1 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 1 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JUMBO STORAGE BAG SUKI, LUNCH BAG  BLACK SKULL.)
# 8 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE)
# 1 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO STORAGE BAG SUKI)
# 3 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PINK POLKADOT, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG RED RETROSPOT)
# 2 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, LUNCH BAG  BLACK SKULL.)
# 1 itemset(s) from tree conditioned on items (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG APPLES)
# 4 itemset(s) from tree conditioned on items (PACK OF 60 PINK PAISLEY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 PINK PAISLEY CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 PINK PAISLEY CAKE CASES, JAM MAKING SET PRINTED)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 PINK PAISLEY CAKE CASES, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 PINK PAISLEY CAKE CASES, REGENCY CAKESTAND 3 TIER)
# 10 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY)
# 2 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG PINK POLKADOT, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 3 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO STORAGE BAG SUKI, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO STORAGE BAG SUKI, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO  BAG BAROQUE BLACK WHITE)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, RED RETROSPOT CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG ALPHABET)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG APPLES)
# 5 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 1 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (60 TEATIME FAIRY CAKE CASES, JUMBO BAG RED RETROSPOT)
# 16 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, RED RETROSPOT CHARLOTTE BAG)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN)
# 3 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, RED RETROSPOT CHARLOTTE BAG)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, CHARLOTTE BAG SUKI DESIGN)
# 2 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOTTE BAG, RED RETROSPOT CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG  BLACK SKULL.)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, PARTY BUNTING)
# 2 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE BAG, RED RETROSPOT CHARLOTTE BAG)
# 1 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG WOODLAND)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CHARLOTTE BAG, LUNCH BAG APPLE DESIGN)
# 5 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES, 60 TEATIME FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 DINOSAUR CAKE CASES, PACK OF 72 SKULL CAKE CASES)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 1 itemset(s) from tree conditioned on items (SET/6 RED SPOTTY PAPER PLATES)
# 1 itemset(s) from tree conditioned on items (LUNCH BOX WITH CUTLERY RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG CHARLIE AND LOLA TOYS)
# 8 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, HEART OF WICKER SMALL)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (JAM MAKING SET PRINTED, SET OF 3 CAKE TINS PANTRY DESIGN)
# 6 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STORAGE BAG SUKI)
# 2 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (JUMBO SHOPPER VINTAGE RED PAISLEY, LUNCH BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (RETROSPOT TEA SET CERAMIC 11 PC)
# 1 itemset(s) from tree conditioned on items (GIN + TONIC DIET METAL SIGN)
# 2 itemset(s) from tree conditioned on items (COOK WITH WINE METAL SIGN)
# 0 itemset(s) from tree conditioned on items (COOK WITH WINE METAL SIGN, GIN + TONIC DIET METAL SIGN)
# 0 itemset(s) from tree conditioned on items (COOK WITH WINE METAL SIGN, PLEASE ONE PERSON METAL SIGN)
# 0 itemset(s) from tree conditioned on items (PAPER CHAIN KIT RETROSPOT)
# 0 itemset(s) from tree conditioned on items (EDWARDIAN PARASOL NATURAL)
# 0 itemset(s) from tree conditioned on items (DOORMAT FANCY FONT HOME SWEET HOME)
# 0 itemset(s) from tree conditioned on items (YOU'RE CONFUSING ME METAL SIGN)
# 0 itemset(s) from tree conditioned on items (CLEAR DRAWER KNOB ACRYLIC EDWARDIAN)
# 2 itemset(s) from tree conditioned on items (SKULL SHOULDER BAG)
# 0 itemset(s) from tree conditioned on items (SKULL SHOULDER BAG, SUKI  SHOULDER BAG)
# 0 itemset(s) from tree conditioned on items (SKULL SHOULDER BAG, DOTCOM POSTAGE)
# 1 itemset(s) from tree conditioned on items (WHITE SPOT RED CERAMIC DRAWER KNOB)
# 0 itemset(s) from tree conditioned on items (CERAMIC STRAWBERRY CAKE MONEY BANK)
# 0 itemset(s) from tree conditioned on items (EDWARDIAN PARASOL BLACK)
# 0 itemset(s) from tree conditioned on items (RETROSPOT LARGE MILK JUG)
# 0 itemset(s) from tree conditioned on items (PIGGY BANK RETROSPOT)
# 0 itemset(s) from tree conditioned on items (AIRLINE LOUNGE,METAL SIGN)
# 0 itemset(s) from tree conditioned on items (CERAMIC CHERRY CAKE MONEY BANK)
# 0 itemset(s) from tree conditioned on items (ZINC WILLIE WINKIE  CANDLE STICK)
# 8 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO BAG PINK POLKADOT)
# 1 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO BAG WOODLAND ANIMALS)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, JUMBO  BAG BAROQUE BLACK WHITE)
# 0 itemset(s) from tree conditioned on items (RECYCLING BAG RETROSPOT, LUNCH BAG RED RETROSPOT)
# 3 itemset(s) from tree conditioned on items (TOY TIDY PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (TOY TIDY PINK POLKADOT, RECYCLING BAG RETROSPOT)
# 0 itemset(s) from tree conditioned on items (TOY TIDY PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (TOY TIDY PINK POLKADOT, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (VINTAGE SNAKES & LADDERS)
# 0 itemset(s) from tree conditioned on items (ANTIQUE GLASS DRESSING TABLE POT)
# 7 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, PARTY BUNTING)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE HEART CHALKBOARD, SET OF 3 CAKE TINS PANTRY DESIGN)
# 4 itemset(s) from tree conditioned on items (HEART OF WICKER SMALL)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER SMALL, NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER SMALL, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER SMALL, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER SMALL, PARTY BUNTING)
# 3 itemset(s) from tree conditioned on items (HEART OF WICKER LARGE)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER LARGE, HEART OF WICKER SMALL)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER LARGE, NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (HEART OF WICKER LARGE, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (WOOD BLACK BOARD ANT WHITE FINISH)
# 0 itemset(s) from tree conditioned on items (COLOUR GLASS T-LIGHT HOLDER HANGING)
# 0 itemset(s) from tree conditioned on items (CREAM HEART CARD HOLDER)
# 0 itemset(s) from tree conditioned on items (ENAMEL FLOWER JUG CREAM)
# 0 itemset(s) from tree conditioned on items (ENAMEL BREAD BIN CREAM)
# 0 itemset(s) from tree conditioned on items (HANGING METAL HEART LANTERN)
# 0 itemset(s) from tree conditioned on items (CLASSIC METAL BIRDCAGE PLANT HOLDER)
# 8 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG SPACEBOY DESIGN)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG WOODLAND)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG APPLE DESIGN)
# 3 itemset(s) from tree conditioned on items (JUMBO BAG DOLLY GIRL DESIGN)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG DOLLY GIRL DESIGN, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG DOLLY GIRL DESIGN, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG DOLLY GIRL DESIGN, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (TRADITIONAL CHRISTMAS RIBBONS)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (CHILLI LIGHTS)
# 0 itemset(s) from tree conditioned on items (HOMEMADE JAM SCENTED CANDLES)
# 0 itemset(s) from tree conditioned on items (GINGHAM HEART  DOORSTOP RED)
# 1 itemset(s) from tree conditioned on items (SMALL HEART MEASURING SPOONS)
# 0 itemset(s) from tree conditioned on items (RED DINER WALL CLOCK)
# 0 itemset(s) from tree conditioned on items (IVORY DINER WALL CLOCK)
# 1 itemset(s) from tree conditioned on items (LARGE HEART MEASURING SPOONS)
# 0 itemset(s) from tree conditioned on items (RED RETROSPOT UMBRELLA)
# 0 itemset(s) from tree conditioned on items (BLUE DINER WALL CLOCK)
# 0 itemset(s) from tree conditioned on items (CHRISTMAS LIGHTS 10 REINDEER)
# 0 itemset(s) from tree conditioned on items (BLACK/BLUE POLKADOT UMBRELLA)
# 4 itemset(s) from tree conditioned on items (SET/20 RED RETROSPOT PAPER NAPKINS)
# 0 itemset(s) from tree conditioned on items (SET/20 RED RETROSPOT PAPER NAPKINS, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (SET/20 RED RETROSPOT PAPER NAPKINS, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SET/20 RED RETROSPOT PAPER NAPKINS, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (SET/20 RED RETROSPOT PAPER NAPKINS, LUNCH BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 2 itemset(s) from tree conditioned on items (RETROSPOT HEART HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (RETROSPOT HEART HOT WATER BOTTLE, SCOTTIE DOG HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (RETROSPOT HEART HOT WATER BOTTLE, CHOCOLATE HOT WATER BOTTLE)
# 1 itemset(s) from tree conditioned on items (HANGING HEART ZINC T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SMALL POPCORN HOLDER)
# 2 itemset(s) from tree conditioned on items (SET/6 RED SPOTTY PAPER CUPS)
# 0 itemset(s) from tree conditioned on items (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY PAPER PLATES)
# 1 itemset(s) from tree conditioned on items (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETROSPOT PAPER NAPKINS)
# 0 itemset(s) from tree conditioned on items (ENGLISH ROSE HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (JAM JAR WITH PINK LID)
# 0 itemset(s) from tree conditioned on items (DELUXE SEWING KIT)
# 0 itemset(s) from tree conditioned on items (PHOTO CUBE)
# 1 itemset(s) from tree conditioned on items (JAM JAR WITH GREEN LID)
# 0 itemset(s) from tree conditioned on items (POLKADOT RAIN HAT)
# 0 itemset(s) from tree conditioned on items (DISCO BALL CHRISTMAS DECORATION)
# 1 itemset(s) from tree conditioned on items (WOODEN BOX OF DOMINOES)
# 0 itemset(s) from tree conditioned on items (3 STRIPEY MICE FELTCRAFT)
# 1 itemset(s) from tree conditioned on items (PICNIC BASKET WICKER SMALL)
# 0 itemset(s) from tree conditioned on items (SET OF 6 SOLDIER SKITTLES)
# 0 itemset(s) from tree conditioned on items (TRADITIONAL WOODEN SKIPPING ROPE)
# 2 itemset(s) from tree conditioned on items (CLOTHES PEGS RETROSPOT PACK 24)
# 0 itemset(s) from tree conditioned on items (CLOTHES PEGS RETROSPOT PACK 24, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (CLOTHES PEGS RETROSPOT PACK 24, PACK OF 72 RETROSPOT CAKE CASES)
# 3 itemset(s) from tree conditioned on items (HAND OVER THE CHOCOLATE   SIGN)
# 0 itemset(s) from tree conditioned on items (HAND OVER THE CHOCOLATE   SIGN, COOK WITH WINE METAL SIGN)
# 0 itemset(s) from tree conditioned on items (HAND OVER THE CHOCOLATE   SIGN, GIN + TONIC DIET METAL SIGN)
# 0 itemset(s) from tree conditioned on items (HAND OVER THE CHOCOLATE   SIGN, PLEASE ONE PERSON METAL SIGN)
# 0 itemset(s) from tree conditioned on items (HAND WARMER OWL DESIGN)
# 2 itemset(s) from tree conditioned on items (HAND WARMER SCOTTY DOG DESIGN)
# 0 itemset(s) from tree conditioned on items (HAND WARMER SCOTTY DOG DESIGN, HAND WARMER OWL DESIGN)
# 0 itemset(s) from tree conditioned on items (HAND WARMER SCOTTY DOG DESIGN, HAND WARMER BIRD DESIGN)
# 0 itemset(s) from tree conditioned on items (TRAVEL SEWING KIT)
# 1 itemset(s) from tree conditioned on items (HAND WARMER RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (FANCY FONT BIRTHDAY CARD,)
# 3 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE IVORY)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE IVORY, ALARM CLOCK BAKELIKE RED)
# 1 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE IVORY, ALARM CLOCK BAKELIKE GREEN)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE IVORY, ALARM CLOCK BAKELIKE PINK)
# 1 itemset(s) from tree conditioned on items (HAND WARMER BIRD DESIGN)
# 0 itemset(s) from tree conditioned on items (SMALL GLASS HEART TRINKET POT)
# 3 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE ORANGE)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE ORANGE, ALARM CLOCK BAKELIKE RED)
# 1 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE ORANGE, ALARM CLOCK BAKELIKE GREEN)
# 0 itemset(s) from tree conditioned on items (ALARM CLOCK BAKELIKE ORANGE, ALARM CLOCK BAKELIKE PINK)
# 0 itemset(s) from tree conditioned on items (CHICK GREY HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (CHOCOLATE HOT WATER BOTTLE)
# 1 itemset(s) from tree conditioned on items (SCOTTIE DOG HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY CERAMIC TRINKET BOX)
# 3 itemset(s) from tree conditioned on items (HOT WATER BOTTLE I AM SO POORLY)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE I AM SO POORLY, CHOCOLATE HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE I AM SO POORLY, SCOTTIE DOG HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (HOT WATER BOTTLE I AM SO POORLY, HOT WATER BOTTLE KEEP CALM)
# 0 itemset(s) from tree conditioned on items (WHITE SKULL HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (DOORMAT FAIRY CAKE)
# 0 itemset(s) from tree conditioned on items (PACK OF 12 RED RETROSPOT TISSUES)
# 0 itemset(s) from tree conditioned on items (PINK DOUGHNUT TRINKET POT)
# 8 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, WHITE HANGING HEART T-LIGHT HOLDER)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG SPACEBOY DESIGN, PARTY BUNTING)
# 10 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROSPOT)
# 3 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY DESIGN, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, WHITE HANGING HEART T-LIGHT HOLDER)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, PACK OF 72 RETROSPOT CAKE CASES)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, PARTY BUNTING)
# 2 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE, LUNCH BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE, LUNCH BAG  BLACK SKULL.)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG PINK POLKADOT, JUMBO BAG PINK POLKADOT)
# 12 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SPACEBOY DESIGN)
# 4 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG PINK POLKADOT, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, WHITE HANGING HEART T-LIGHT HOLDER)
# 3 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG  BLACK SKULL., LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG  BLACK SKULL., LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, RED RETROSPOT CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, PACK OF 72 RETROSPOT CAKE CASES)
# 2 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG CARS BLUE, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG CARS BLUE, LUNCH BAG SPACEBOY DESIGN)
# 5 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN, LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG SUKI DESIGN, LUNCH BAG SPACEBOY DESIGN)
# 4 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG APPLE DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG APPLE DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG APPLE DESIGN, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG APPLE DESIGN, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG WOODLAND, LUNCH BAG APPLE DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (GUMBALL COAT RACK)
# 3 itemset(s) from tree conditioned on items (BATHROOM METAL SIGN)
# 0 itemset(s) from tree conditioned on items (BATHROOM METAL SIGN, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (BATHROOM METAL SIGN, DOTCOM POSTAGE)
# 0 itemset(s) from tree conditioned on items (BATHROOM METAL SIGN, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (PHOTO FRAME CORNICE)
# 1 itemset(s) from tree conditioned on items (LADIES & GENTLEMEN METAL SIGN)
# 1 itemset(s) from tree conditioned on items (SCANDINAVIAN REDS RIBBONS)
# 0 itemset(s) from tree conditioned on items (METAL SIGN TAKE IT OR LEAVE IT)
# 1 itemset(s) from tree conditioned on items (TOILET METAL SIGN)
# 1 itemset(s) from tree conditioned on items (CANDLEHOLDER PINK HANGING HEART)
# 0 itemset(s) from tree conditioned on items (ASSORTED COLOUR MINI CASES)
# 0 itemset(s) from tree conditioned on items (I'M ON HOLIDAY METAL SIGN)
# 0 itemset(s) from tree conditioned on items (PICTURE DOMINOES)
# 0 itemset(s) from tree conditioned on items (SET 20 NAPKINS FAIRY CAKES DESIGN)
# 0 itemset(s) from tree conditioned on items (BALLOONS  WRITING SET)
# 0 itemset(s) from tree conditioned on items (SET/10 PINK POLKADOT PARTY CANDLES)
# 1 itemset(s) from tree conditioned on items (KITCHEN METAL SIGN)
# 0 itemset(s) from tree conditioned on items (SET OF 4 ENGLISH ROSE PLACEMATS)
# 0 itemset(s) from tree conditioned on items (SET OF 4 ENGLISH ROSE COASTERS)
# 0 itemset(s) from tree conditioned on items (BIRD HOUSE HOT WATER BOTTLE)
# 0 itemset(s) from tree conditioned on items (JAZZ HEARTS PURSE NOTEBOOK)
# 0 itemset(s) from tree conditioned on items (SET OF 9 HEART SHAPED BALLOONS)
# 0 itemset(s) from tree conditioned on items (FAIRY CAKE FLANNEL ASSORTED COLOUR)
# 0 itemset(s) from tree conditioned on items (FAMILY PHOTO FRAME CORNICE)
# 0 itemset(s) from tree conditioned on items (APPLE BATH SPONGE)
# 0 itemset(s) from tree conditioned on items (STRAWBERRY BATH SPONGE)
# 0 itemset(s) from tree conditioned on items (GROW YOUR OWN BASIL IN ENAMEL MUG)
# 0 itemset(s) from tree conditioned on items (TRIPLE PHOTO FRAME CORNICE)
# 0 itemset(s) from tree conditioned on items (RETROSPOT CIGAR BOX MATCHES)
# 6 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG  BLACK SKULL., PARTY BUNTING)
# 10 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE)
# 1 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, LUNCH BAG RED RETROSPOT)
# 2 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, LUNCH BAG SPACEBOY DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, LUNCH BAG SPACEBOY DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG CARS BLUE, PARTY BUNTING)
# 0 itemset(s) from tree conditioned on items (SET OF 3 BUTTERFLY COOKIE CUTTERS)
# 1 itemset(s) from tree conditioned on items (SET OF 3 HEART COOKIE CUTTERS)
# 4 itemset(s) from tree conditioned on items (PACK OF 72 SKULL CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 SKULL CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 SKULL CAKE CASES, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 SKULL CAKE CASES, 60 TEATIME FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 72 SKULL CAKE CASES, LUNCH BAG RED RETROSPOT)
# 3 itemset(s) from tree conditioned on items (72 SWEETHEART FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (72 SWEETHEART FAIRY CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (72 SWEETHEART FAIRY CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (72 SWEETHEART FAIRY CAKE CASES, 60 TEATIME FAIRY CAKE CASES)
# 4 itemset(s) from tree conditioned on items (PACK OF 60 SPACEBOY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 SPACEBOY CAKE CASES, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 SPACEBOY CAKE CASES, PACK OF 60 DINOSAUR CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 SPACEBOY CAKE CASES, PACK OF 72 SKULL CAKE CASES)
# 0 itemset(s) from tree conditioned on items (PACK OF 60 SPACEBOY CAKE CASES, 60 TEATIME FAIRY CAKE CASES)
# 0 itemset(s) from tree conditioned on items (3 PIECE SPACEBOY COOKIE CUTTER SET)
# 0 itemset(s) from tree conditioned on items (HEART IVORY TRELLIS SMALL)
# 0 itemset(s) from tree conditioned on items (HEART IVORY TRELLIS LARGE)
# 0 itemset(s) from tree conditioned on items (CHOCOLATE BOX RIBBONS)
# 0 itemset(s) from tree conditioned on items (PINK DRAWER KNOB ACRYLIC EDWARDIAN)
# 0 itemset(s) from tree conditioned on items (ROMANTIC PINKS RIBBONS)
# 4 itemset(s) from tree conditioned on items (SET/5 RED RETROSPOT LID GLASS BOWLS)
# 0 itemset(s) from tree conditioned on items (SET/5 RED RETROSPOT LID GLASS BOWLS, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (SET/5 RED RETROSPOT LID GLASS BOWLS, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SET/5 RED RETROSPOT LID GLASS BOWLS, PACK OF 72 RETROSPOT CAKE CASES)
# 0 itemset(s) from tree conditioned on items (SET/5 RED RETROSPOT LID GLASS BOWLS, LUNCH BAG RED RETROSPOT)
# 5 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT)
# 0 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT, NATURAL SLATE HEART CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (VICTORIAN GLASS HANGING T-LIGHT, PARTY BUNTING)
# 1 itemset(s) from tree conditioned on items (DOORMAT RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (RED  HARMONICA IN BOX)
# 1 itemset(s) from tree conditioned on items (BLUE HARMONICA IN BOX)
# 0 itemset(s) from tree conditioned on items (DOORMAT HEARTS)
# 2 itemset(s) from tree conditioned on items (PLASTERS IN TIN SKULLS)
# 0 itemset(s) from tree conditioned on items (PLASTERS IN TIN SKULLS, PLASTERS IN TIN SPACEBOY)
# 0 itemset(s) from tree conditioned on items (PLASTERS IN TIN SKULLS, PLASTERS IN TIN WOODLAND ANIMALS)
# 2 itemset(s) from tree conditioned on items (LOVEBIRD HANGING DECORATION WHITE)
# 0 itemset(s) from tree conditioned on items (LOVEBIRD HANGING DECORATION WHITE, DOTCOM POSTAGE)
# 0 itemset(s) from tree conditioned on items (LOVEBIRD HANGING DECORATION WHITE, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SET OF 20 KIDS COOKIE CUTTERS)
# 1 itemset(s) from tree conditioned on items (SINGLE HEART ZINC T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (4 TRADITIONAL SPINNING TOPS)
# 0 itemset(s) from tree conditioned on items (SET OF 72 RETROSPOT PAPER  DOILIES)
# 0 itemset(s) from tree conditioned on items (ROTATING SILVER ANGELS T-LIGHT HLDR)
# 0 itemset(s) from tree conditioned on items (NATURAL SLATE RECTANGLE CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (AIRLINE BAG VINTAGE TOKYO 78)
# 0 itemset(s) from tree conditioned on items (10 COLOUR SPACEBOY PEN)
# 0 itemset(s) from tree conditioned on items (SILVER HANGING T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SLEEPING CAT ERASERS)
# 0 itemset(s) from tree conditioned on items (CARD CIRCUS PARADE)
# 0 itemset(s) from tree conditioned on items (12 PENCILS TALL TUBE SKULLS)
# 0 itemset(s) from tree conditioned on items (CARD BIRTHDAY COWBOY)
# 0 itemset(s) from tree conditioned on items (RIBBON REEL MAKING SNOWMEN)
# 0 itemset(s) from tree conditioned on items (PENS ASSORTED FUNNY FACE)
# 12 itemset(s) from tree conditioned on items (JUMBO BAG STRAWBERRY)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG STRAWBERRY, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG STRAWBERRY, JUMBO STORAGE BAG SUKI)
# ...
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG VINTAGE ALPHABET, RED RETROSPOT CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG VINTAGE ALPHABET, CHARLOTTE BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG VINTAGE ALPHABET, WOODLAND CHARLOTTE BAG)
# 0 itemset(s) from tree conditioned on items (CHARLOTTE BAG VINTAGE ALPHABET, CHARLOTTE BAG PINK POLKADOT)
# 10 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG ALPHABET DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG APPLE DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG CARS BLUE)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, LUNCH BAG WOODLAND)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE LEAF DESIGN, JUMBO BAG VINTAGE LEAF)
# 0 itemset(s) from tree conditioned on items (TRIPLE HOOK ANTIQUE IVORY ROSE)
# 0 itemset(s) from tree conditioned on items (SINGLE ANTIQUE ROSE HOOK IVORY)
# 0 itemset(s) from tree conditioned on items (MINIATURE ANTIQUE ROSE HOOK IVORY)
# 0 itemset(s) from tree conditioned on items (ZINC T-LIGHT HOLDER STARS SMALL)
# 0 itemset(s) from tree conditioned on items (REGENCY SUGAR TONGS)
# 0 itemset(s) from tree conditioned on items (DOORMAT KEEP CALM AND COME IN)
# 4 itemset(s) from tree conditioned on items (SPOTTY BUNTING)
# 0 itemset(s) from tree conditioned on items (SPOTTY BUNTING, PARTY BUNTING)
# 0 itemset(s) from tree conditioned on items (SPOTTY BUNTING, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (SPOTTY BUNTING, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (SPOTTY BUNTING, LUNCH BAG RED RETROSPOT)
# 8 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO BAG APPLES)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO BAG PINK POLKADOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO BAG ALPHABET)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO STORAGE BAG SUKI)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, LUNCH BAG APPLE DESIGN)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE LEAF, JUMBO SHOPPER VINTAGE RED PAISLEY)
# 5 itemset(s) from tree conditioned on items (JUMBO BAG PEARS)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PEARS, JUMBO BAG APPLES)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG PEARS, JUMBO BAG VINTAGE LEAF)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG PEARS, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PEARS, JUMBO BAG ALPHABET)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PEARS, LUNCH BAG APPLE DESIGN)
# 2 itemset(s) from tree conditioned on items (JUMBO BAG DOILEY PATTERNS)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG DOILEY PATTERNS, JUMBO BAG VINTAGE LEAF)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG DOILEY PATTERNS, JUMBO BAG RED RETROSPOT)
# 2 itemset(s) from tree conditioned on items (LUNCH BAG DOILEY PATTERN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOILEY PATTERN, JUMBO BAG DOILEY PATTERNS)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG DOILEY PATTERN, LUNCH BAG APPLE DESIGN)
# 0 itemset(s) from tree conditioned on items (BUNDLE OF 3 RETRO NOTE BOOKS)
# 0 itemset(s) from tree conditioned on items (BUNDLE OF 3 ALPHABET EXERCISE BOOKS)
# 2 itemset(s) from tree conditioned on items (REGENCY TEA PLATE ROSES)
# 0 itemset(s) from tree conditioned on items (REGENCY TEA PLATE ROSES, ROSES REGENCY TEACUP AND SAUCER)
# 0 itemset(s) from tree conditioned on items (REGENCY TEA PLATE ROSES, GREEN REGENCY TEACUP AND SAUCER)
# 2 itemset(s) from tree conditioned on items (REGENCY TEAPOT ROSES)
# 0 itemset(s) from tree conditioned on items (REGENCY TEAPOT ROSES, ROSES REGENCY TEACUP AND SAUCER)
# 0 itemset(s) from tree conditioned on items (REGENCY TEAPOT ROSES, REGENCY CAKESTAND 3 TIER)
# 3 itemset(s) from tree conditioned on items (REGENCY TEA PLATE GREEN)
# 0 itemset(s) from tree conditioned on items (REGENCY TEA PLATE GREEN, REGENCY TEA PLATE ROSES)
# 0 itemset(s) from tree conditioned on items (REGENCY TEA PLATE GREEN, GREEN REGENCY TEACUP AND SAUCER)
# 1 itemset(s) from tree conditioned on items (REGENCY TEA PLATE GREEN, ROSES REGENCY TEACUP AND SAUCER)
# 1 itemset(s) from tree conditioned on items (REGENCY MILK JUG PINK)
# 2 itemset(s) from tree conditioned on items (REGENCY SUGAR BOWL GREEN)
# 0 itemset(s) from tree conditioned on items (REGENCY SUGAR BOWL GREEN, REGENCY MILK JUG PINK)
# 0 itemset(s) from tree conditioned on items (REGENCY SUGAR BOWL GREEN, REGENCY TEAPOT ROSES)
# 2 itemset(s) from tree conditioned on items (REGENCY TEA PLATE PINK)
# 0 itemset(s) from tree conditioned on items (REGENCY TEA PLATE PINK, REGENCY TEA PLATE GREEN)
# 1 itemset(s) from tree conditioned on items (REGENCY TEA PLATE PINK, REGENCY TEA PLATE ROSES)
# 0 itemset(s) from tree conditioned on items (RABBIT NIGHT LIGHT)
# 0 itemset(s) from tree conditioned on items (PARISIENNE JEWELLERY DRAWER)
# 0 itemset(s) from tree conditioned on items (SET OF 10 LED DOLLY LIGHTS)
# 0 itemset(s) from tree conditioned on items (RED METAL BOX TOP SECRET)
# 0 itemset(s) from tree conditioned on items (PARISIENNE KEY CABINET)
# 0 itemset(s) from tree conditioned on items (SET 6 PAPER TABLE LANTERN HEARTS)
# 0 itemset(s) from tree conditioned on items (SILVER BELLS TABLE DECORATION)
# 0 itemset(s) from tree conditioned on items (PARISIENNE CURIO CABINET)
# 0 itemset(s) from tree conditioned on items (SMALL CERAMIC TOP STORAGE JAR)
# 0 itemset(s) from tree conditioned on items (LARGE CERAMIC TOP STORAGE JAR)
# 0 itemset(s) from tree conditioned on items (SILVER STARS TABLE DECORATION)
# 0 itemset(s) from tree conditioned on items (GLASS BON BON JAR)
# 0 itemset(s) from tree conditioned on items (CLASSIC GLASS COOKIE JAR)
# 0 itemset(s) from tree conditioned on items (CLASSIC CAFE SUGAR DISPENSER)
# 0 itemset(s) from tree conditioned on items (JINGLE BELL HEART DECORATION)
# 0 itemset(s) from tree conditioned on items (SET 6 PAPER TABLE LANTERN STARS)
# 2 itemset(s) from tree conditioned on items (GARDENERS KNEELING PAD KEEP CALM)
# 0 itemset(s) from tree conditioned on items (GARDENERS KNEELING PAD KEEP CALM, WHITE HANGING HEART T-LIGHT HOLDER)
# 0 itemset(s) from tree conditioned on items (GARDENERS KNEELING PAD KEEP CALM, JUMBO BAG RED RETROSPOT)
# 1 itemset(s) from tree conditioned on items (GARDENERS KNEELING PAD CUP OF TEA)
# 0 itemset(s) from tree conditioned on items (KNEELING MAT HOUSEWORK  DESIGN)
# 0 itemset(s) from tree conditioned on items (JINGLE BELL HEART ANTIQUE SILVER)
# 0 itemset(s) from tree conditioned on items (SET OF 3 HANGING OWLS OLLIE BEAK)
# 0 itemset(s) from tree conditioned on items (SET OF 3 WOODEN HEART DECORATIONS)
# 1 itemset(s) from tree conditioned on items (SET OF 60 I LOVE LONDON CAKE CASES)
# 1 itemset(s) from tree conditioned on items (SET OF 60 PANTRY DESIGN CAKE CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 36 DOILIES PANTRY DESIGN)
# 1 itemset(s) from tree conditioned on items (SET OF 60 VINTAGE LEAF CAKE CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 4 KNICK KNACK TINS LONDON)
# 1 itemset(s) from tree conditioned on items (SET OF TEA COFFEE SUGAR TINS PANTRY)
# 4 itemset(s) from tree conditioned on items (SET OF 3 REGENCY CAKE TINS)
# 0 itemset(s) from tree conditioned on items (SET OF 3 REGENCY CAKE TINS, REGENCY CAKESTAND 3 TIER)
# 0 itemset(s) from tree conditioned on items (SET OF 3 REGENCY CAKE TINS, SET OF 3 CAKE TINS PANTRY DESIGN)
# 0 itemset(s) from tree conditioned on items (SET OF 3 REGENCY CAKE TINS, ROSES REGENCY TEACUP AND SAUCER)
# 0 itemset(s) from tree conditioned on items (SET OF 3 REGENCY CAKE TINS, GREEN REGENCY TEACUP AND SAUCER)
# 0 itemset(s) from tree conditioned on items (TREASURE TIN GYMKHANA DESIGN)
# 0 itemset(s) from tree conditioned on items (TREASURE TIN BUFFALO BILL)
# 0 itemset(s) from tree conditioned on items (BISCUIT TIN 50'S CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (BUBBLEGUM RING ASSORTED)
# 1 itemset(s) from tree conditioned on items (SMALL WHITE HEART OF WICKER)
# 1 itemset(s) from tree conditioned on items (SET OF 3 WOODEN STOCKING DECORATION)
# 0 itemset(s) from tree conditioned on items (SET OF 3 WOODEN SLEIGH DECORATIONS)
# 2 itemset(s) from tree conditioned on items (SET OF 3 WOODEN TREE DECORATIONS)
# 0 itemset(s) from tree conditioned on items (SET OF 3 WOODEN TREE DECORATIONS, SET OF 3 WOODEN STOCKING DECORATION)
# 0 itemset(s) from tree conditioned on items (SET OF 3 WOODEN TREE DECORATIONS, SET OF 3 WOODEN HEART DECORATIONS)
# 0 itemset(s) from tree conditioned on items (POPCORN HOLDER)
# 1 itemset(s) from tree conditioned on items (LARGE WHITE HEART OF WICKER)
# 0 itemset(s) from tree conditioned on items (BLUE VINTAGE SPOT BEAKER)
# 1 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (CHRISTMAS STAR WISH LIST CHALKBOARD)
# 0 itemset(s) from tree conditioned on items (SPACEBOY CHILDRENS BOWL)
# 0 itemset(s) from tree conditioned on items (VINTAGE DONKEY TAIL GAME)
# 0 itemset(s) from tree conditioned on items (BISCUIT TIN VINTAGE CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (GLASS APOTHECARY BOTTLE PERFUME)
# 0 itemset(s) from tree conditioned on items (GLASS APOTHECARY BOTTLE ELIXIR)
# 0 itemset(s) from tree conditioned on items (GLASS APOTHECARY BOTTLE TONIC)
# 2 itemset(s) from tree conditioned on items (JUMBO BAG 50'S CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG 50'S CHRISTMAS, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG 50'S CHRISTMAS, PAPER CHAIN KIT 50'S CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (SPACEBOY CHILDRENS CUP)
# 0 itemset(s) from tree conditioned on items (PANTRY MAGNETIC  SHOPPING LIST)
# 0 itemset(s) from tree conditioned on items (SKETCHBOOK MAGNETIC SHOPPING LIST)
# 0 itemset(s) from tree conditioned on items (WHITE WICKER STAR)
# 0 itemset(s) from tree conditioned on items (BOX OF 6 MINI VINTAGE CRACKERS)
# 0 itemset(s) from tree conditioned on items (GIANT 50'S CHRISTMAS CRACKER)
# 0 itemset(s) from tree conditioned on items (VINTAGE LEAF MAGNETIC NOTEPAD)
# 0 itemset(s) from tree conditioned on items (BOX OF 6 MINI 50'S CRACKERS)
# 0 itemset(s) from tree conditioned on items (VINTAGE CHRISTMAS BUNTING)
# 0 itemset(s) from tree conditioned on items (SET OF 12 FAIRY CAKE BAKING CASES)
# 1 itemset(s) from tree conditioned on items (SET OF 12 MINI LOAF BAKING CASES)
# 2 itemset(s) from tree conditioned on items (SET OF 6 TEA TIME BAKING CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 6 TEA TIME BAKING CASES, SET OF 12 FAIRY CAKE BAKING CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 6 TEA TIME BAKING CASES, SET OF 12 MINI LOAF BAKING CASES)
# 3 itemset(s) from tree conditioned on items (SET OF 6 SNACK LOAF BAKING CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 6 SNACK LOAF BAKING CASES, SET OF 12 FAIRY CAKE BAKING CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 6 SNACK LOAF BAKING CASES, SET OF 12 MINI LOAF BAKING CASES)
# 0 itemset(s) from tree conditioned on items (SET OF 6 SNACK LOAF BAKING CASES, SET OF 6 TEA TIME BAKING CASES)
# 0 itemset(s) from tree conditioned on items (VINTAGE CHRISTMAS STOCKING)
# 0 itemset(s) from tree conditioned on items (VINTAGE CHRISTMAS GIFT SACK)
# 0 itemset(s) from tree conditioned on items (6 GIFT TAGS VINTAGE CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (6 GIFT TAGS 50'S CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (ROLL WRAP VINTAGE CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (ROLL WRAP VINTAGE SPOT)
# 0 itemset(s) from tree conditioned on items (ROLL WRAP 50'S CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (ROLL WRAP 50'S RED CHRISTMAS)
# 0 itemset(s) from tree conditioned on items (SET OF 4 KNICK KNACK TINS DOILY)
# 4 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE DOILY)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE DOILY, JUMBO BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE DOILY, JUMBO BAG VINTAGE LEAF)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE DOILY, JUMBO BAG APPLES)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG VINTAGE DOILY, JUMBO BAG 50'S CHRISTMAS)
# 6 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, LUNCH BAG RED RETROSPOT)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, JUMBO BAG VINTAGE DOILY)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, LUNCH BAG  BLACK SKULL.)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, LUNCH BAG SUKI DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, LUNCH BAG SPACEBOY DESIGN)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG VINTAGE DOILY, LUNCH BAG APPLE DESIGN)
# 0 itemset(s) from tree conditioned on items (IVORY WICKER HEART LARGE)
# 0 itemset(s) from tree conditioned on items (DECORATIVE WICKER HEART LARGE)
# 0 itemset(s) from tree conditioned on items (DECORATIVE WICKER HEART MEDIUM)
# 0 itemset(s) from tree conditioned on items (IVORY WICKER HEART MEDIUM)
# 0 itemset(s) from tree conditioned on items (SET 6 SCHOOL MILK BOTTLES IN CRATE)
# 1 itemset(s) from tree conditioned on items (LOVE HOT WATER BOTTLE)
# 1 itemset(s) from tree conditioned on items (HOT WATER BOTTLE KEEP CALM)
# 1 itemset(s) from tree conditioned on items (HAND WARMER RED LOVE HEART)
# 0 itemset(s) from tree conditioned on items (HOME SWEET HOME CUSHION COVER)
# 0 itemset(s) from tree conditioned on items (BELLE JARDINIERE CUSHION COVER)
# 0 itemset(s) from tree conditioned on items (FOOT STOOL HOME SWEET HOME)
# 0 itemset(s) from tree conditioned on items (HOME SWEET HOME HANGING HEART)
# 0 itemset(s) from tree conditioned on items (SPACEBOY MINI BACKPACK)
# 0 itemset(s) from tree conditioned on items (PLAYING CARDS KEEP CALM & CARRY ON)
# 0 itemset(s) from tree conditioned on items (SET 12 COLOUR PENCILS SPACEBOY)
# 0 itemset(s) from tree conditioned on items (PLAYING CARDS JUBILEE UNION JACK)
# 0 itemset(s) from tree conditioned on items (VINTAGE DOILY TRAVEL SEWING KIT)
# 0 itemset(s) from tree conditioned on items (SET 12 COLOUR PENCILS DOLLY GIRL)
# 0 itemset(s) from tree conditioned on items (WALL ART STOP FOR TEA)
# 0 itemset(s) from tree conditioned on items (BOX OF 6 CHRISTMAS CAKE DECORATIONS)
# 0 itemset(s) from tree conditioned on items (MINI LIGHTS WOODLAND MUSHROOMS)
# 0 itemset(s) from tree conditioned on items (TRADITIONAL PICK UP STICKS GAME)
# 0 itemset(s) from tree conditioned on items (TRADITIONAL NAUGHTS & CROSSES)
# 0 itemset(s) from tree conditioned on items (VINTAGE DOILY JUMBO BAG RED)
# 0 itemset(s) from tree conditioned on items (LUNCH BAG PAISLEY PARK)
# 0 itemset(s) from tree conditioned on items (JUMBO BAG PAISLEY PARK)
#            support
# count  1739.000000
# mean      0.016724
# std       0.009475
# min       0.010044
# 25%       0.011257
# 50%       0.013441
# 75%       0.018244
# max       0.109661

# %%
print(frequent_itemsets)
# Out:
#        support                                           itemsets
# 0     0.109661               (WHITE HANGING HEART T-LIGHT HOLDER)
# 1     0.022272              (KNITTED UNION FLAG HOT WATER BOTTLE)
# 2     0.020816                   (RED WOOLLY HOTTIE WHITE HEART.)
# 3     0.018439                     (SET 7 BABUSHKA NESTING BOXES)
# 4     0.014896                              (WHITE METAL LANTERN)
# ...        ...                                                ...
# 1734  0.010335  (LUNCH BAG VINTAGE DOILY, LUNCH BAG SPACEBOY D...
# 1735  0.011257  (LUNCH BAG VINTAGE DOILY, LUNCH BAG APPLE DESIGN)
# 1736  0.011451  (HOT WATER BOTTLE KEEP CALM, LOVE HOT WATER BO...
# 1737  0.013053  (HOT WATER BOTTLE KEEP CALM, CHOCOLATE HOT WAT...
# 1738  0.010578  (HAND WARMER RED LOVE HEART, HAND WARMER OWL D...
#
# [1739 rows x 2 columns]

# %%
def association_rules(df,metric="support" ,min_threshold=0.3):

    # metrics for association rules
    metric_dict = {
        "antecedent support": lambda _, sA, __: sA,
        "consequent support": lambda _, __, sC: sC,
        "support": lambda sAC, _, __: sAC,
        "confidence": lambda sAC, sA, _: sAC/sA
        }

    columns_ordered = ["antecedent support", "consequent support", "support", "confidence"]

    # get dict of {frequent itemset} -> support
    keys = df['itemsets'].values
    values = df['support'].values
    frozenset_vect = np.vectorize(lambda x: frozenset(x))
    frequent_items_dict = dict(zip(frozenset_vect(keys), values))

    # prepare buckets to collect frequent rules
    rule_antecedents = []
    rule_consequents = []
    rule_supports = []

    # iterate over all frequent itemsets
    for k in frequent_items_dict.keys():
        sAC = frequent_items_dict[k]
        # to find all possible combinations
        for idx in range(len(k)-1, 0, -1):
            # of antecedent and consequent
            for c in combinations(k, r=idx):
                antecedent = frozenset(c)
                consequent = k.difference(antecedent)

                sA = frequent_items_dict[antecedent]
                sC = frequent_items_dict[consequent]

                score = metric_dict[metric](sAC, sA, sC)
                if score >= min_threshold:
                    rule_antecedents.append(antecedent)
                    rule_consequents.append(consequent)
                    rule_supports.append([sAC, sA, sC])

    # check if frequent rule was generated
    if not rule_supports:
        return pd.DataFrame(
            columns=["antecedents", "consequents"] + columns_ordered)

    else:
        # generate metrics
        rule_supports = np.array(rule_supports).T.astype(float)
        df_res = pd.DataFrame(
            data=list(zip(rule_antecedents, rule_consequents)),
            columns=["antecedents", "consequents"])

        sAC = rule_supports[0]
        sA = rule_supports[1]
        sC = rule_supports[2]
        for m in columns_ordered:
            df_res[m] = metric_dict[m](sAC, sA, sC)

        return df_res

# %%
rules = association_rules(frequent_itemsets,metric="support", min_threshold=0.01)
rules.sort_values('confidence', ascending = False, inplace = True)
rules.head(10)
# Out:
#                                             antecedents  \
# 2010       (SUKI  SHOULDER BAG, JAM MAKING SET PRINTED)
# 2734  (REGENCY TEA PLATE ROSES, REGENCY TEA PLATE PINK)
# 1305                                (HERB MARKER THYME)
# 2039  (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN T...
# 1304                             (HERB MARKER ROSEMARY)
# 403   (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE ...
# 2736  (REGENCY TEA PLATE GREEN, REGENCY TEA PLATE PINK)
# 2730                           (REGENCY TEA PLATE PINK)
# 2168  (PINK REGENCY TEACUP AND SAUCER, REGENCY CAKES...
# 2720  (ROSES REGENCY TEACUP AND SAUCER, REGENCY TEA ...
#
#                                consequents  antecedent support  \
# 2010                      (DOTCOM POSTAGE)            0.010578
# 2734             (REGENCY TEA PLATE GREEN)            0.013053
# 1305                (HERB MARKER ROSEMARY)            0.011500
# 2039  (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.012082
# 1304                   (HERB MARKER THYME)            0.011645
# 403          (RED RETROSPOT CHARLOTTE BAG)            0.012761
# 2736             (REGENCY TEA PLATE ROSES)            0.013489
# 2730             (REGENCY TEA PLATE GREEN)            0.014799
# 2168     (GREEN REGENCY TEACUP AND SAUCER)            0.016061
# 2720             (REGENCY TEA PLATE ROSES)            0.011063
#
#       consequent support   support  confidence
# 2010            0.034354  0.010141    0.958716
# 2734            0.018487  0.012373    0.947955
# 1305            0.011645  0.010723    0.932489
# 2039            0.024844  0.011209    0.927711
# 1304            0.011500  0.010723    0.920833
# 403             0.050172  0.011742    0.920152
# 2736            0.021593  0.012373    0.917266
# 2730            0.018487  0.013489    0.911475
# 2168            0.049250  0.014605    0.909366
# 2720            0.021593  0.010044    0.907895
